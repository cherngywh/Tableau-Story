# %%
import pandas as pd

# %%
df01 = pd.read_csv("csv/JC-201701-citibike-tripdata.csv")
df02 = pd.read_csv("csv/JC-201702-citibike-tripdata.csv")
df03 = pd.read_csv("csv/JC-201703-citibike-tripdata.csv")
df04 = pd.read_csv("csv/JC-201704-citibike-tripdata.csv")
df05 = pd.read_csv("csv/JC-201705-citibike-tripdata.csv")
df06 = pd.read_csv("csv/JC-201706-citibike-tripdata.csv")

# %%
df07 = pd.read_csv("csv/JC-201707-citibike-tripdata.csv")
df08 = pd.read_csv("csv/JC-201708 citibike-tripdata.csv")
df09 = pd.read_csv("csv/JC-201709-citibike-tripdata.csv")
df10 = pd.read_csv("csv/JC-201710-citibike-tripdata.csv")
df11 = pd.read_csv("csv/JC-201711-citibike-tripdata.csv")
df12 = pd.read_csv("csv/JC-201712-citibike-tripdata.csv")

# %%
columns = df01.columns
columns
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
df12.head()
# Out:
#    Trip Duration      Start Time       Stop Time  Start Station ID  \
# 0            452  12/1/2017 0:00  12/1/2017 0:08              3183
# 1            159  12/1/2017 0:04  12/1/2017 0:07              3187
# 2            175  12/1/2017 0:17  12/1/2017 0:19              3186
# 3            455  12/1/2017 0:50  12/1/2017 0:57              3194
# 4            670  12/1/2017 0:55  12/1/2017 1:06              3194
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0     Exchange Place               40.716247               -74.033459
# 1          Warren St               40.721124               -74.038051
# 2      Grove St PATH               40.719586               -74.043117
# 3    McGinley Square               40.725340               -74.067622
# 4    McGinley Square               40.725340               -74.067622
#
#    End Station ID      End Station Name  End Station Latitude  \
# 0            3199          Newport Pkwy             40.728745
# ...

# %%
year = pd.concat([df01, df02, df03, df04, df05, df06, df07, df08, df09, df10, df11, df12])
year
# Out:
#        Trip Duration        Start Time         Stop Time  Start Station ID  \
# 0                148     1/1/2017 0:21     1/1/2017 0:24              3276
# 1               1283     1/1/2017 0:24     1/1/2017 0:45              3183
# 2                372     1/1/2017 0:38     1/1/2017 0:44              3183
# 3               1513     1/1/2017 0:38     1/1/2017 1:03              3194
# 4                639     1/1/2017 1:47     1/1/2017 1:58              3183
# 5                258     1/1/2017 1:56     1/1/2017 2:00              3186
# 6                663     1/1/2017 2:12     1/1/2017 2:23              3270
# 7                567     1/1/2017 2:15     1/1/2017 2:25              3192
# 8                551     1/1/2017 2:16     1/1/2017 2:25              3192
# 9                573     1/1/2017 2:22     1/1/2017 2:31              3212
# 10               535     1/1/2017 2:22     1/1/2017 2:31              3212
# ...

# %%
year.to_csv("2017.csv")
